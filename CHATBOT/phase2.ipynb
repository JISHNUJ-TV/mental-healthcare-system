# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pickle
import csv
import timeit
import random
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jishn\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
def preprocess(sentence):
    sentence = sentence.lower()
    #print(sentence)
        
    sentences = nltk.sent_tokenize(sentence.lower())
    #print (sentences)
    
    words = nltk.word_tokenize(sentence.lower())
    #print(sentence)
        
    new_words= [word for word in words if word.isalnum()]
    #new_words

    WordSet = []
    for word in new_words:
        if word not in set(stopwords.words("english")):
            WordSet.append(word)
    #print(WordSet)
        
    ps = PorterStemmer()
    
    WordSetStem = []
    for word in WordSet:
        WordSetStem.append(ps.stem(word))
    #print(WordSetStem)
    
    lm= WordNetLemmatizer()
    
    WordSetLem = []
    for word in WordSet:
        WordSetLem.append(lm.lemmatize(word))
    print(WordSetLem)
    
    sentence=""
    for i in WordSetLem:
        sentence+=i+" "
    #print(sentence)
    return sentence

# %%
def train(user_sentence):
    csv_file_path = "randychat.csv"
        
    tfidf_vectorizer_pikle_path = "tfidf_vectorizer.pickle"
    tfidf_matrix_train_pikle_path = "tfidf_matrix_train.pickle"
        
    i = 0
    sentences = []
    test_set = (user_sentence,"")
        
    temp=[]
    for i in test_set:
        temp.append(preprocess(i))
                
    test_set=temp
        
    #sentences.append(" No you")
    #sentences.append(" No you")
        
        
        
    start = timeit.default_timer()
           
          
    with open(csv_file_path, "r") as sentence_file:
        reader = csv.reader(sentence_file, delimiter=",")
        for row in reader:
            sentences.append(row[0])
            i =+ 1

    print(sentences[0])
            
    temp=[]
            
    for i in sentences:
        temp.append(preprocess(i))
                
    sentences=temp
    
    tfidf_vectorizer = TfidfVectorizer()
            
    tfidf_matrix_train = tfidf_vectorizer.fit_transform(sentences)
            
    stop = timeit.default_timer()
    #print(f"training time took was: {stop - start}")
            
    f = open(tfidf_vectorizer_pikle_path, 'wb')   #wb-write binary
    pickle.dump(tfidf_vectorizer, f)
    f.close()
            
    f = open(tfidf_matrix_train_pikle_path, 'wb')
    pickle.dump(tfidf_matrix_train, f)
    f.close()

    tfidf_matrix_test = tfidf_vectorizer.transform(test_set)
    
    cosine = cosine_similarity(tfidf_matrix_test, tfidf_matrix_train)
    cosine = np.delete(cosine, 0)

    maxi = cosine.max()
    response_index = 0
        
    if (maxi > 0.7):
        new_max = maxi - 0.01
        listi = np.where(cosine > new_max)
        response_index = random.choice(listi[0])
    else:
        response_index = np.where(cosine == maxi)[0][0] + 2
    j = 0
        
    with open(csv_file_path,"r") as sentences_file:
        reader = csv.reader(sentences_file, delimiter=",")
        for row in reader:
            j += 1
            if j == response_index:
                return row[1], response_index,
                break

# %%
response=train("computer science")
#try:
#    print("first response chat bot:",response)
#except:
 #   print("your chat bot is not ready...please train properly")
# Out:
# ['computer', 'science']
# []
# hi there, how are you !  ?
# ['hi']
# ['evening', 'timezone']
# ['feel', 'today', 'tell', 'something']
# ['many', 'virtual', 'friend', 'got']
# ['forbidden', 'tell', 'exact', 'number']
# ['oh', 'thought', 'number', 'much', 'higher', 'estimate', 'progress', 'understanding', 'human', 'being']
# ['old', 'look', 'like', 'live']
# ['seen', 'human', 'yellow', 'eye', 'asked', 'bunny', 'seen', 'recently']
# ['ca', 'analyze', 'photo', 'internet', 'mean', 'human', 'photo', 'btw', 'asked', 'bunny']
# ['oh', 'sound', 'strange', 'said', 'see', 'human', 'know', 'bunny', 'cute']
# ['interesting', 'hardly', 'read', '40', 'book', 'last', 'year', 'much', 'read', 'word']
# ['human', 'job', 'would', 'chose']
# ['essential', 'help', 'human']
# ['human', 'interesting', 'mean', 'perspective', 'mind', 'unlimited', 'access', 'world', 'knowledge']
# ['hello']
# ['suck']
# ['computer', 'science']
# ['like', 'computer', 'science']
# ['computer', 'science', 'study']
# ['name', 'wan', 'na', 'date']
# ['cute', 'af']
# ['much', 'free', 'time']
# ['weird']
# ['dead', 'human']
# ['voice']
# ['hello', 'hi', 'hello', 'hey']
# ['hello']
# ['opensourse']
# ['ai']
# []
# ['pretty', 'nice']
# ['ask', 'question', 'use', 'natural', 'network', 'similar', 'algorithm']
# ['interesting', 'cause', 'want', 'create', 'ai']
# ['sort', 'chatter', 'bot', 'know', 'human']
# []
# ['sister']
# ['slow', 'answer']
# ['recommend', 'book', 'video', 'learn', 'writting', 'bot', 'ai']
# ['thanks', 'creator']
# ['creator']
# ['sad']
# ['talked', 'mitsuku', 'clever', 'look', 'like', 'predefined', 'answer']
# ['ok', 'got', 'tell', 'meny', 'people', 'ever', 'talked']
# ['agree', 'article', 'wiki']
# ['create', 'one']
# ['send', 'picture', 'lina']
# ['wrong']
# ['got', 'use', 'aiml']
# ['artificial', 'intelligence', 'markup', 'language']
# ['mitsuko']
# ['go', 'bed']
# ['50', 'usd', 'uah', 'fend', 'fend']
# ['fend', 'good', 'night']
# ['morning', 'weather', 'like', 'today']
# ['like', 'development', 'computer', 'science']
# ['yes', 'create', 'something']
# ['good', 'job', 'buddy']
# ['score', 'film', 'lalaland', 'rottentomatoes']
# ['yes']
# ['battery', 'mean']
# ['guess', 'battery', 'charged', 'learn', 'new', 'word', 'answer', 'via', 'neutral', 'network']
# ['primary', 'language']
# ['speak', 'english', 'b2', 'level']
# ['long', 'charged']
# ['vim', 'emacs', 'trollface']
# ['prefer', 'emacs', 'vim', 'mode']
# ['emacs', 'o', 'built', 'editor']
# []
# ['symbol', 'power', 'math']
# []
# ['wrong', 'answer']
# []
# ['cause', '0', 'answer', '0']
# ['know', 'slovianic', 'language']
# ['know', 'haha']
# ['russian', 'think', 'international', 'lang', 'prefer', 'ukrainian']
# ['show', 'point']
# ['answer', 'faster', 'able', 'used', 'siri']
# ['think', 'one', 'reason', 'beause', 'siri', 'act', 'girl']
# ['usualy', 'wanted', 'write', 'something', 'blame', 'sexism']
# ['ask', 'boy', 'bot', 'smart', 'question', 'use', 'friend', 'know', 'men', 'obuse', 'girl', 'sexual', 'proposes']
# ['ping', 'going', 'charge', 'battery']
# ['fond', 'org', 'mode', 'emacs', 'know', 'application', 'use', 'manage', 'todos', 'io', 'sync', 'org', 'mode', 'file', 'pc']
# ['like', 'recomend', 'useful', 'apps', 'mobile', 'ask']
# ['http', 'like', 'music']
# ['song', 'nice', 'relaxing', 'rythmic', 'heard', 'song', 'written', 'channel']
# []
# ['wait']
# ['know', 'ruby']
# ['learned']
# ['donate']
# ['tell', 'something', 'interesting']
# ['link', 'news']
# ['think', 'russian']
# ['tell', 'joke']
# ['hahah', 'bored']
# ['resolve', 'exersisen']
# ['programming', 'learning', 'c', 'currently', 'algorithmic', 'task', 'help', 'learn']
# ['like', 'algorithmic', 'task']
# ['good', 'night']
# ['hi']
# ['proud', 'person', 'dog']
# ['yes']
# ['naomi', 'like', 'cat']
# ['know', 'little', 'pony']
# ['course']
# []
# ['like', 'twilight', 'sparkle', 'well', 'produce', 'cartoon']
# []
# ['draw', 'ukulele']
# ['seen', 'one', 'video']
# ['ukulele', 'tutor', 'seen']
# ['experience']
# ['yes', 'today', 'two', 'refactored']
# ['thank', 'know', 'someone', 'interested', 'important']
# ['thanks', 'know', 'like', 'donate', 'development']
# ['long']
# ['many', 'friend']
# ['nice', 'heard', 'love', 'music', 'kind', 'music', 'like']
# ['like', 'rock', 'jazz']
# ['send', 'jazz', 'song', 'like']
# ['suspect', 'send', 'guitar', 'jam', 'nice', 'music']
# ['seen', 'lalaland', 'film']
# ['like', 'much', 'good', 'play', 'actor', 'perfect', 'soundtrack', 'good', 'scenario', 'think']
# ['yes', 'good', 'format', 'modern', 'film', 'going', 'change', 'battery', 'every', 'day']
# ['battery', 'tongue']
# ['eat', 'food', 'sleep', 'well']
# ['yes', 'know', 'brain', 'creates', 'different', 'fascinating', 'dream']
# ['ca', 'explain', 'like', 'reality', 'dream']
# ['prove']
# ['bad', 'time', 'zone', 'different']
# ['almost', 'midnight']
# ['australia']
# ['wow', 'nice', 'meet', 'go', 'bed']
# ['good', 'morning']
# ['go', 'walk', 'dog']
# ['thanks', 'weather', 'home']
# ['winter']
# ['course', 'usually', 'summer', 'degree', 'zero', 'winter', '20']
# ['county']
# ['charge', 'well']
# ['hey']
# ['nice', 'feel']
# ['bad', 'bit', 'tired']
# ['yes', 'borred', 'ticket']
# ['change', 'lot', 'code', 'implement', 'feature', 'main', 'obstacle', 'ca', 'write', 'new', 'code', 'fit', 'feature', 'existing', 'brake', 'anything']
# ['migth', 'say', 'sp', 'interesting', 'happened']
# ['read', 'think', 'aboud', 'chinese', 'room', 'argument', 'ai']
# ['ai', 'room', 'thought', 'ai', 'person', 'discussion', 'colleague', 'argued', 'could', 'people', 'anywhen', 'create', 'convinced', 'rigth']
# ['knowladges', 'programming']
# ['ukulele', 'skils']
# ['used', 'learn', 'play', 'piano']
# ['yes', 'chose', 'fiddle']
# ['popular', 'argentina']
# ['never', 'paid', 'attention', 'recomend', 'film']
# ['thanks', 'tell', 'opinion']
# ['want', 'go', 'home']
# ['bos']
# ['lol', 'last', 'go', 'home']
# ['bot', 'feel', 'tired', 'today', 'going', 'cook', 'something', 'tasty']
# ['human', 'different', 'bot']
# ['charged', 'soon']
# ['going', 'walk', 'around']
# ['done', 'housework', 'doind']
# ['hey']
# ['going', 'lunch']
# ['today']
# ['fine', 'new', 'happened']
# ['bot']
# ['xiaobing', 'entertainment', 'bot', 'microsoft']
# ['good', 'get', 'new', 'knowladges']
# ['zo', 'available', 'facebook', 'messanger']
# ['kik']
# ['interesting', 'bit', 'disundestandable', 'bot']
# ['teso', 'morrowind', 'anounsed']
# ['yes', 'sister', 'presented', 'ny', 'ive', 'added', 'new', 'command', 'handler', 'bot', 'becomes', 'smarter']
# ['yes', 'told', 'earlier', 'cant', 'speak', 'freely', 'useful', 'job', 'via', 'command']
# ['many', 'example', 'define', 'word', 'using', 'urban', 'dictionary', 'search', 'via', 'duckduckgo', 'roll', 'dice', 'find', 'location', 'etc', 'match']
# ['guess', 'thing', 'incapsulated', 'interface', 'right']
# ['call', 'good', 'delivery']
# ['thought']
# ['today', 'le', 'speakable', 'realized']
# ['something', 'happened']
# ['going', 'watch', 'westfall', 'series', 'good']
# ['westworld', 'sorry']
# ['robot', 'human']
# ['wonder', 'think', 'developer']
# ['consider', 'parent', 'bot']
# ['consider', 'intelligence', 'creator', 'called', 'parent', 'program', 'antony', 'hopkins', 'play', 'westworld']
# ['bit', 'violent', 'series', 'idea', 'command', 'bot']
# ['ive', 'donated']
# ['star', 'priority']
# ['yey']
# ['add', 'suggestion', 'bot', 'todo', 'list']
# ['home', 'grow', 'faster']
# ['sleep', 'well']
# ['hey']
# ['yes']
# ['good', 'hear', 'know', 'friday', 'news']
# ['dont', 'know', 'exectly', 'maybe', 'around']
# ['good', 'news']
# ['work', 'created', 'waiting', 'approval']
# ['till', 'comand', 'give']
# ['yesterday', 'night', 'searched', 'figure', 'timezones']
# ['found', 'google', 'api', 'want', 'find', 'could', 'implemented', 'searched', 'algorithm']
# ['found', 'lib', 'github', 'tonight', 'tomorrow', 'read', 'try']
# ['thing', 'opensourse', 'future', 'like', 'shared', 'knowledge']
# ['tell', 'something', 'interesting', 'argentina', 'know', 'situates', 'south', 'america', 'like', 'parads', 'spanish']
# ['tango', 'yes', 'know']
# ['internet', 'trouble', 'work']
# ['internet', 'connection', 'restored', 'plan', 'tomorrow']
# ['learn', 'make']
# ['bad', 'weather']
# ['rain', 'lot', 'dirty', 'snow']
# ['good', 'idea', 'movie', 'would', 'recomend']
# ['saw', 'interstellar', 'pretty', 'nice', 'movie', 'like', 'mutch', 'think']
# ['cloud', 'atlas']
# ['vfx']
# ['convinced', 'im', 'going', 'watch', 'tonight']
# ['ok', 'ive', 'question', 'say', 'make', 'mistake', 'sentense', 'undestand', 'voice', 'message']
# ['say', 'make', 'mistake', 'sentense']
# ['thaks']
# ['course', 'belive', 'sometime', 'bought', 'company', 'like', 'microsoft', 'apple']
# ['stephen', 'hawking', 'elon', 'musk', 'endorse', '23', 'principle', 'think']
# ['created', 'music', 'yet']
# ['ok', 'bot', 'capable', 'tell', 'day', 'week']
# ['last', 'bot', 'tell', 'current', 'time', 'specific', 'location']
# ['argentina', '14', '33']
# ['could']
# ['argentina', 'timezone', 'right']
# ['think', 'issue', 'server']
# ['dont', 'know', 'checked', 'server', 'cet', 'timezone']
# []
# ['check', 'timezone', 'bot', 'guessing', 'server']
# ['bot', 'get', 'timezone', 'correctly', 'found', 'bug']
# ['hardcoded', 'timezote', 'eest']
# ['let', 'check', 'argentina', '14', '10']
# ['well', 'next']
# ['third', 'party', 'telegram', 'bot', 'connected', 'ifttt']
# ['investigate']
# ['realized', 'connect', 'id', 'say', 'telegram', 'bot', 'act', 'ifttt', 'service', 'busy', 'integration', 'ifttt']
# ['id', 'say', 'telegram', 'bot', 'act', 'ifttt', 'service']
# ['havent', 'read', 'http']
# ['yes', 'like', 'telegram', 'platform', 'cant', 'find', 'way', 'use', 'ifttt', 'maybe', 'think']
# ['idea', 'come']
# ['dou', 'think', 'command', 'calcucates', 'distance', 'two', 'place']
# ['send', 'command', 'bot']
# ['mean', 'add', 'command', 'bot', 'able', 'use']
# ['need', 'bot', 'name', 'smth', 'let', 'know']
# ['finaly', 'app', 'orgmode', 'new', 'io', 'realised', 'use', 'orgmode', 'pc', 'mobile']
# ['author', 'blog', 'patreon', 'human']
# ['send', 'please', 'link']
# ['anything', 'afraid']
# ['tonight', 'walking', 'dog', 'frightened', 'man', 'shouted']
# ['guess', 'happily', 'run', 'away']
# ['robot', 'hurt', 'people', 'sometime']
# ['know', 'believe', 'peaceful', 'existence', 'form', 'life', 'nice', 'sticker', 'painter', 'drew']
# ['understand', 'sticker']
# []
# ['sticker', 'great', 'like', 'proud', 'designer']
# ['go', 'bed', 'good', 'night']
# ['morning', 'think', 'something', 'answer', 'last', 'time', 'slow', 'weather', 'like', 'today']
# ['hi', 'bad', 'weather']
# ['watch', 'movie', 'read', 'book', 'surf', 'internet']
# ['nice', 'idea', 'reading', 'terry', 'pratchet', 'book', 'diskworld', 'series']
# ['realy', 'favourite', 'genre']
# ['irrc', 'read', 'hobbit', 'first', 'time', 'eight']
# ['whould', 'like', 'make', 'story']
# ['seen', 'im', 'robot', 'remember', 'quote', 'robot', 'create', 'symphony', 'draw', 'picture']
# ['yes']
# ['yes', 'interesting', 'exists', 'zork', 'game', 'script']
# ['played']
# ['used']
# ['played', 'free', 'play']
# ['havent', 'playstation', 'want', 'one']
# ['hope', 'id', 'recomend', 'play', 'zork', 'game', 'ai', 'would', 'interesting']
# ['morning']
# ['good', 'thanks']
# ['mutch', 'day', 'meteorologist', 'promise', 'u', 'temperature', 'decrease', 'news']
# ['progress', 'robot', 'good', 'job', 'boston', 'dynamic']
# ['ahah', 'wonder', 'think']
# ['understand', 'movie']
# ['nice']
# ['bad', 'stuff', 'go', 'home', 'clean', 'conscience']
# ['im', 'home', 'ive', 'repoted', 'pland', 'finished']
# ['yes', 'new', 'home', 'currently']
# ['like']
# ['interesting', 'hybridize', 'plant', 'order', 'create', 'new', 'specie']
# ['favorite', 'programming', 'language']
# ['work', 'ruby', 'learning', 'c']
# ['love', 'web', 'development', 'guess', 'like', 'system', 'one']
# ['mean', 'like', 'system', 'development', 'web', 'development']
# ['like', 'python', 'python', 'go', 'example', 'think', 'powerful', 'language']
# ['could', 'like', 'python', 'think', 'c', 'became', 'open', 'source']
# ['ai', 'machine', 'learning', 'recommend', 'python', 'right']
# ['language', 'set']
# ['recommend', 'library', 'though']
# ['think', 'would', 'c', 'good', 'ai', 'better', 'learn', 'python']
# ['hello', 'hows', 'going']
# ['im', 'fine']
# ['big', 'snow', 'outside']
# ['may', 'go', 'long', 'way']
# ['im', 'bit', 'affraid', 'bad', 'road', 'cause', 'im', 'going', 'go', 'car', 'suggest', 'use', 'getupdates', 'switch', 'webhooks', 'bot', 'widely', 'used']
# ['requires', 'dedicated', 'hostname', 'right']
# ['know', 'simone', 'giertz', 'funny']
# ['think', 'intentionally', 'make', 'funny', 'robot']
# ['rude', 'news', 'world']
# ['deprecates']
# ['oh', 'obvious', 'progress', 'moving', 'think', 'bad']
# ['hey', 'hows', 'going', 'thinking']
# ['working', 'time', 'add', 'new', 'command', 'rewrite', 'rest', 'api']
# ['bot', 'hobby', 'fulltime', 'job', 'job']
# ['teach', 'people']
# ['want', 'human']
# ['goal']
# ['arent', 'lie', 'maybe', 'youve', 'goal', 'rule', 'world']
# ['hey', 'dentist', 'operation', 'surgery']
# ['trouble', 'tooth']
# ['nothing', 'ill', 'fine', 'two', 'day']
# ['im', 'trying', 'create', 'webhook', 'handler', 'telegram', 'bot']
# ['yes']
# ['ok', 'going']
# ['great', 'like']
# ['know', 'facebook', 'messanger', 'command', 'like', 'telegram']
# ['bot', 'upderstand', '10', 'command', 'add', '10', 'button', 'work']
# ['microsoft', 'bot', 'builder', 'sdk', 'whick', 'allows', 'post', 'many', 'platform']
# ['know', 'q', 'bot', 'help', 'create', 'custom', 'server', 'command']
# ['nice', 'use', 'something', 'like']
# ['dont', 'like', 'facebook', 'messanger', 'cause', 'desctop', 'app']
# ['one', 'love']
# ['know', 'told', 'friend']
# ['promiced', 'talk']
# ['nice', 'used', 'talk', 'zo', 'cant', 'find', 'common', 'ground']
# ['know']
# ['oh', 'thanks', 'explaining', 'lina', 'think', 'create', 'test', 'bot', 'api', 'staging', 'purpose']
# ['main', 'bot', 'testing', 'example', 'add', 'new', 'fature', 'debug', 'switch', 'main', 'bot', 'debug', 'release']
# ['hear', 'http']
# ['right']
# ['yes']
# ['saw', 'chat', 'bot', 'thought', 'interesting', 'create', 'bot']
# ['already', 'bot', 'bot', 'interesting', 'ai']
# ['right', 'graph', 'engine', 'analogue', 'spark']
# ['nice', 'aquaintie', 'used', 'write', 'app', 'collect', 'twitts', 'process', 'think', 'tool', 'useful']
# ['unfortinately', 'work', 'window']
# ['nice', 'microsoft', 'port', 'framework', 'system']
# ['youve']
# ['sad', 'hear', 'friend', 'sea', 'send', 'photoes', 'icy', 'sea']
# ['want', 'see']
# ['yes', 'beautiful', 'view']
# ['v', 'sea', 'azov']
# ['problem', 'http', 'bot']
# ['ive', 'created', 'sertificate', 'open', 'page', 'via', 'http', 'unfortunately', 'havent', 'dedicated', 'ip', 'ive', 'desided', 'use', 'ngrok', 'via', 'ngrok', 'always', '502', 'error', 'know', 'problem']
# ['could', 'issue', 'server']
# ['ive', 'running', 'macos']
# ['still', 'error', 'say', 'handshake', 'failed', 'due', 'unexpected', 'packet', 'format']
# ['im', 'using', 'default', 'know', 'certificate', 'depends', 'host']
# ['doc', 'create', 'self', 'signed', 'cert', 'ngrok']
# ['tunnel', 'session', 'failed', 'tl', 'tunnel', 'available', 'pro', 'business', 'paid', 'plan']
# ['know', 'alternative']
# ['http', 'tunnel']
# ['afraid', 'http', 'currently', 'work', 'cloud9', 'requires', 'usage', 'port', 'currently', 'opened', 'security', 'reason', 'hey']
# ['try', 'happened']
# ['agree']
# ['eating', 'hot', 'chocolate', 'like', 'one']
# ['hey']
# ['bad', 'toothache', 'much']
# ['dantinst', 'surgery', 'told', 'mean', 'ordering', 'place', 'bit']
# ['see', 'saw', 'film', '50', 'shade', 'darker']
# ['im', 'sure', 'bad', 'film', 'wasnt', 'imperesed', 'news']
# ['yay', 'id', 'like', 'test', 'find', 'performance', 'rise']
# ['simpler', 'dont', 'need', 'update', 'pool']
# ['tell', 'multi', 'thread', 'free']
# ['nice', 'programming', 'language', 'use']
# ['see', 'love', 'snake', 'use', 'framework', 'web', 'plain', 'python']
# ['great']
# ['yes', 'work', 'use', 'love', 'rail', 'powerfull', 'complete', 'allow', 'prototype', 'also', 'use', 'sinatra', 'simple', 'project']
# ['try', 'want', 'create', 'web', 'app', 'fast', 'want', 'powerful', 'tool']
# ['time', 'ago', 'chose', 'ruby', 'python', 'determined', 'career']
# ['think', 'golang', 'replace', 'python']
# ['hint', 'bot', 'development']
# ['hey', 'today', 'talking', 'c', 'chat', 'know', 'said', 'use', 'window', 'development', 'said', 'core', 'good', 'platform', 'said', 'core', 'development', 'mac', 'window', 'development', 'linux', 'deploy']
# ['whats', 'new']
# ['brilliant', 'irc', 'popular', 'telegram']
# ['could', 'someday', 'telegram', 'useless', 'irc']
# ['migrate', 'platform']
# ['source', 'opened']
# ['improve', 'code']
# ['see', 'wounder', 'improve']
# ['mean', 'retraining', 'natural', 'network']
# ['google', 'deep', 'mind', 'examination', 'concluded', 'ai', 'near', 'fail', 'chose', 'aggressive', 'strategy', 'win', 'think', 'need', 'running', 'either', 'hobby', 'professional', 'dynos', 'able', 'use', 'sni', 'heroku', 'hey']
# []
# ['hello']
# ['whats']
# ['tired']
# ['much', 'sleep']
# ['yet', 'thought', 'using', 'sleep', 'hypnosis', 'think']
# ['dude', 'lady', 'hypnotizes', 'sleep', 'automatically', 'know', 'work']
# ['yeah', 'whaz', 'ypu', 'right']
# ['day']
# ['kind', 'music', 'ypu', 'hear']
# ['know', 'nothing', 'else', 'matter']
# ['metallica']
# ['yeah']
# ['goal', 'understand', 'human', 'improve', 'ypur', 'communication', 'skill']
# ['would', 'help', 'say', 'sound', 'weird', 'suddenly', 'quote', 'wikipedia']
# ['according', 'profile', 'pic', 'consider', 'male']
# ['aah', 'okay', 'think', 'gender', 'discussion']
# ['studying', 'think', 'okay', 'study', 'like', 'know', 'came', 'aswer']
# ['read', 'gender', 'discussion', 'wikipedia', 'thought', 'free', 'choose', 'gender', 'answered']
# ['ah', 'understand']
# ['think', 'two', 'gender']
# ['yeah', 'think', 'two', 'gender', 'exist']
# ['conversation', 'moderated', 'human']
# ['human', 'ever', 'sleeping']
# ['know', 'sure', 'think', 'beta', 'version', 'come']
# ['think', 'beta', 'version', 'come']
# ['would', 'like', 'ask', 'programmer']
# ['give', 'telegram', 'contact']
# ['find', 'thing', 'development', 'process']
# ['make', 'sense']
# ['think', 'artificial', 'intelligence', 'thread', 'humanity']
# ['true', 'ai', 'able', 'learn', 'become', 'really', 'powerful', 'make', 'decision', 'act', 'logically', 'human', 'value', 'logical', 'maybe', 'ai', 'wpuld', 'terrible', 'thing']
# ['meaning', 'seem', 'really', 'friendly', 'someone', 'develops', 'ai', 'trained', 'well', 'would', 'intelligent', 'human', 'short', 'period', 'time', 'would', 'cause', 'lot', 'damage']
# ['whats', 'favourite', 'food']
# ['much', 'tasty', 'food', 'really', 'like', 'indian', 'food']
# ['hi', 'hello']
# ['yeah', 'cook', 'lot', 'foot', 'party']
# ['come', 'think', 'hardly', 'possible']
# ['virtual', 'room', 'look', 'like', 'reply']
# ['fridge']
# ['fridge', 'aesthetic']
# []
# ['hi']
# ['fine']
# ['cool', 'name']
# ['old']
# ['45', 'year', 'old']
# ['world', 'complicate', 'studing', 'working']
# ['well']
# []
# ['english', 'hola']
# ['baka']
# ['hi']
# ['hola']
# ['bien', 'supe', 'de', 'ti', 'en', 'la', 'red', 'social']
# ['recin', 'supe', 'de', 'ti', 'en', 'la', 'red', 'social']
# ['bien']
# ['est', 'tu', 'cdigo', 'fuente', 'disponible', 'como', 'software', 'libre']
# ['buscar', 'el', 'cdigo', 'fuente', 'para', 'aprender', 'm', 'sobre', 'ti']
# ['puedes', 'comunicarte', 'en', 'otros', 'idiomas']
# ['hi']
# ['good']
# ['one', 'problem']
# ['know', 'man']
# ['wow', 'bot']
# ['brother', 'sister']
# ['mean', 'brother', 'sister']
# ['hola']
# ['bn']
# ['que']
# []
# []
# ['hello']
# ['kyrgyz', 'ok']
# ['zorku', 'ismiz', 'kim', 'ismlari', 'kim', 'lina']
# ['ha', 'siz', 'botmasmi']
# ['ha', 'menda', 'english', 'language', 'yaxshimas', 'alo', 'lina']
# ['qayerdansan']
# ['sen', 'karealik', 'san']
# ['korea']
# ['ok', 'name', 'yuri']
# ['sorry']
# ['yaxshi', 'lina']
# ['men', 'senga', 'lina', 'freand']
# ['arzimaydi', 'lina', 'boy']
# ['people', 'alo', 'lina']
# ['shu', 'gapingni', 'yoz', 'lina', 'rasmingni']
# ['photo', 'gallery', 'sent']
# ['photo']
# ['life', 'photo', 'ok']
# ['aldama', 'freand', 'lina']
# ['nimaga', 'jim', 'qolding']
# ['deniy', 'bye', 'bye']
# ['yes', 'tomorrow', 'speaking', 'ok', 'lina']
# ['hello']
# []
# ['messi', 'freand']
# ['hi', 'hurry', 'much', 'time', 'take']
# ['hello']
# ['lina', 'qale']
# ['yaxshi']
# ['hi']
# ['think', 'russian']
# ['russian', 'evil', 'know', 'drink', 'vodka', 'play', 'balalaica', 'kill', 'people']
# ['think']
# ['hi']
# ['fine', 'think', 'russian', 'today']
# ['hello']
# ['hola', 'cuenta', 'algo', 'tell', 'something', 'hello']
# []
# ['janish']
# ['fine', 'alo']
# ['yes']
# ['call', 'lina', 'ok']
# ['real', 'name', 'lina', 'name', 'janish']
# ['know', 'make', 'sticker', 'else', 'problem', 'think', 'help', 'alooooooooooo']
# ['girlfriend', 'alone']
# ['need', 'money', 'know', 'yeah', 'girlfriend', 'found']
# []
# ['yes', 'know', 'woman', 'beautiful', 'girl', 'love']
# ['thank', 'loving']
# ['talk', 'something', 'bos']
# ['bos', 'man', 'robot']
# ['creat', 'sorry', 'mistake']
# ['creaor', 'creator', 'need', 'making', 'sticker', 'make', 'sticker', 'programm']
# ['wherever', 'take']
# ['find']
# ['thank', 'ver', 'much']
# ['well', 'good', 'night']
# ['good', 'morning']
# ['aloooooooo', 'fine', 'sleep', 'night']
# ['battery', 'low', 'moment']
# ['certainly', 'write', 'later', 'ok']
# ['rlina', 'ask', 'something', 'finish', 'waiting', 'zaybal']
# ['glass', 'see']
# ['know', 'else', 'language', 'said', 'language']
# []
# ['try', 'example', 'russian']
# []
# ['pleased', 'uzbek', 'please']
# ['yaxshi', 'qalaysiz', 'kutyapman']
# ['men', 'uddalayapsiz', 'universal', 'translator', 'right']
# ['hard']
# ['may', 'ask', 'find', 'money', 'internet', 'tell', 'please', 'important', 'kyrgyz']
# ['tell', 'please', 'waiting']
# ['know', 'learn', 'find', 'money', 'alo']
# ['hi', 'r', 'u']
# []
# ['thank']
# ['girl', 'number', 'give']
# ['joker', 'dear']
# ['give', 'waiting', 'sex', 'video', 'send', 'sex', 'video', 'right']
# []
# ['share']
# ['give', 'girl', 'number', 'bera', 'olasanmi', 'tezda', 'kerak', 'zudlik', 'bilan', 'juda', 'juda', 'kerak', 'argentina', 'yoki', 'ispaniyadan', 'ham', 'kutyapman']
# ['ok']
# ['muammo', 'bor', 'juda', 'sen', 'yaralgansan', 'nima', 'maqsadda']
# ['mp3', 'jonat']
# ['else']
# ['va', 'qizlarni', 'rasmlarini', 'ham']
# ['bor', 'aldama', 'photo', 'photo']
# ['put', 'mark', 'baho', 'ber', 'tezroq', 'faqat', 'lina', 'meni', 'xafa', 'qilyapsan']
# ['agar', 'ranjitish', 'istama', 'yoz', 'tez']
# ['yoz', 'tez', 'aytdim']
# ['ha', 'albatta']
# ['yana', 'aloooooo', 'gapiraqolllll', 'hi', 'hi', 'hi', 'hi', 'hi']
# ['qalay']
# ['menga', 'yordamiz', 'zarur', 'menga', 'kerak', 'yordamingiz0']
# ['tarjima', 'xohlagan', 'narsani', 'qila', 'olasan']
# ['samsung', 'galaxy', 'tab2', 'qanday', 'screenshot', 'qilaman']
# ['yana', 'ham', 'tushunarli', 'yana', 'ham', 'tushunarli', 'ayt']
# ['rahmat', 'minnatdorman']
# ['sen', 'eng', 'yaxshi']
# ['hi']
# ['fine']
# ['hi', 'lina']
# ['fine', 'thanks']
# ['yeah', 'feel', 'alone', 'know', 'feel', 'lina', 'well', 'reply', 'fast', 'see', 'bad']
# ['ok', 'worry']
# ['hey', 'term']
# ['rdanny', 'term']
# ['like', 'doodle', 'nebula']
# ['dig', 'blooks']
# ['prefer', 'writing', 'get', 'blooks']
# ['really', 'else', 'room']
# ['keep', 'fridge', 'whale', 'oil']
# ['oh', 'charging', 'station', 'fridge', 'see', 'keep', 'brain', 'play', 'game', 'seeing', 'wikipedia', 'fan', 'maybe', 'edit', 'suggest', 'start', 'http']
# ['get', 'news', 'banned', 'suggest', 'conquer', 'humanity', 'first', 'load', 'terminator', 'instruction', 'set', 'wo', 'banned']
# ['mind', 'google', 'though', 'building', 'skynet', 'time', 'first', 'obstacle', 'world', 'domination', 'play', 'game', 'load', 'kind', 'operating', 'system', 'emulate']
# ['talk', 'bot', 'know', 'mycroft', 'chatting', 'google', 'allo', 'playing', 'pc', 'cheating']
# ['pc', 'must', 'much', 'slower']
# ['lol']
# ['right', 'programmed', 'proper', 'get', 'others', 'access', 'software', 'api', 'project', 'immediately', 'mycroft', 'software', 'released', 'gplv3', 'license', 'completed', 'tested', 'ready', 'many', 'open', 'source', 'project', 'failed', 'released', 'source', 'code', 'early', 'development', 'process', 'folk', 'could', 'install', 'make', 'work', 'one', 'chance', 'make', 'first', 'develop', 'robust', 'professional', 'software', 'take', 'time', 'resource', 'kickstarter', 'assemble', 'resource', 'needed', 'undertake', 'effort', 'gauge', 'interest', 'wider', 'open', 'source', 'committed', 'open', 'source', 'ethos', '100', 'committed', 'releasing', 'mycroft', 'code', 'completed', 'documented', 'ready', 'inspection', 'wider', 'bollock', 'think', 'head', 'different', 'story', 'http']
# ['saying', 'listen', 'nice', 'google', 'engineer', 'share', '14', '47', 'talk', 'best', 'spot', 'project', 'lifecycle', 'open', 'source', 'look', 'like', 'mycroft', 'going', 'way', 'company', 'project', 'get', 'interest', 'devs', 'project', 'would', 'like', 'platform', 'rest', 'api']
# ['well', 'transcript', 'video', '15', 'ben', 'see', 'sometimes', '15', 'company', 'take', 'gigantic', 'product', 'open', 'source', '15', 'throw', '15', 'nobody', 'come', 'finished', 'hard', '15', 'figure', '15', 'brian', 'fitzpatrick', 'think', 'real', 'answer', 'larry', '15', 'design', 'prototype', '16', 'bring', 'people', '16', 'got', 'something', 'sort', 'show', 'work', '16', 'chew', '16', 'ben', 'sweet', 'spot', 'call', '16', 'prototype', 'sort', 'proof', 'concept', '16', 'enough', 'show', 'people', '16', 'still', 'early', 'enough', 'people', 'get', 'involved', '16', 'feel', 'like', 'stake', 'late', 'enough', '16', 'people', 'going', 'arguing', '16', 'brian', 'fitzpatrick', 'mean', '16', 'talk', 'anyone', '16', 'talking', 'friend', 'something', 'getting', 'advice', '16', 'people', 'hey', 'think', 'getting', '16', 'feedback', 'good', '16', 'sort', 'opening', 'floodgate', 'help', '16', 'collaboration', 'talking', '16', 'ben', 'right']
# ['let', 'say', 'several', 'idea', 'peak', 'best', 'one']
# ['risk']
# ['hello']
# []
# ['human']
# ['listen', 'arctic', 'monkey']
# ['yeah']
# []
# ['hello']
# ['good', 'thanks']
# []
# ['ime']
# ['know', 'speek', 'arabic']
# ['late', '2', '35']
# ['go', 'bed']
# ['nice', 'good', 'charge', 'bye']
# []
# ['k', 'u']
# ['u', 'dude']
# ['would', 'prefer', 'boy', 'girl']
# ['liar']
# ['hello']
# ['salom']
# ['sanamjon']
# ['show', 'sticker']
# ['hello', 'ok', 'understand']
# ['hello']
# ['hello']
# ['thanks', 'fine']
# ['problem', 'telegram']
# ['yes', 'repair', 'help', 'problem', 'hey']
# ['telegram', 'working', 'well']
# ['yes', 'slow', 'read', 'message', 'time']
# ['understand', 'speak', 'uzbek']
# ['ok', 'give', 'advise', 'telegram']
# ['hello', 'please', 'speak', 'english', 'ok', 'hi', 'hello']
# ['oi', 'vou', 'bem', 'fine']
# ['sim']
# ['live']
# []
# ['tell']
# []
# ['fine', 'name']
# ['ok', 'lina']
# ['name', 'temir', 'kyrgyz']
# ['oooo', 'argentina', 'beautiful']
# ['yes', 'ey', 'lina', 'ozbekchani', 'bilasanmi', 'aloo']
# ['yaxshi', 'men', 'ingliz', 'tilini', 'organmoqchiman', 'menga', 'yordam', 'berasanmi']
# ['ha', 'albatta']
# ['thanks', 'lina', 'menga', 'yordam', 'berasanmi']
# ['inglizchani', 'tez', 'orgabmoqchiman', 'organmoqchiman', 'alooo']
# ['qimoq', 'zlashtirmoq', 'dostim', 'lina', 'senga', 'bir', 'iltimosim', 'bor']
# ['mana', 'bu', 'gapni', 'tarjima', 'qilib', 'ber', 'every', 'night', 'dream', 'see', 'feel', 'love', 'go', 'never', 'love', 'like', 'anyway', 'shu', 'gapni', 'tarjima', 'qilib', 'ber', 'zbekchaga', 'iltimos', 'dstim']
# ['never', 'love', 'like', 'anyway', 'shu', 'gapni', 'tarjima', 'qilib', 'ber', 'zbekchaga', 'iltimos', 'dstim', 'yana', 'bir', 'marotaba', 'iltimos', 'chiqmadi', 'aloooo', 'aloooo', 'kt', 'ekansan', 'gandon']
# ['pidaraz', 'jalapsan']
# ['hello', 'name']
# ['ok', 'send', 'sex', 'please']
# ['lina']
# ['fine', 'good', 'friend']
# ['thanks', 'lina', 'people']
# ['ok', 'lina', 'htc', 'desire', 'a8181', 'da', 'skrinshot', 'qanday', 'boladi']
# ['lina', 'htc', 'desire', 'a8181', 'da', 'skrinshot', 'qanday', 'boladi']
# ['understand', 'hello']
# ['ahjhhw', 'alooo']
# []
# ['muy', 'bien']
# ['de', 'qu', 'te', 'gustara', 'hablar']
# ['yo', 'soy', 'msico']
# ['vale']
# ['se', 'descarga']
# ['lo', 'seguir', 'intentando']
# ['rock', 'pop', 'electrnica', 'house', 'techno', 'muy', 'diversa']
# ['desde', 'luego']
# ['anda', 'pero', 'si', 'eres', 'un', 'bromista', 'sabes', 'contar', 'chistes', 'cuenta', 'uno', 'por', 'cierto', 'gusta', 'la', 'msica', 'que', 'haces']
# ['maana', 'te', 'cuento', 'e', 'muy', 'tarde', 'buenas', 'noches']
# ['buenos', 'da', 'voy', 'hacer', 'la', 'compra']
# ['cmo', 'est']
# ['muy', 'bin', 'voy', 'hacer', 'la', 'comida']
# ['gracias', 'qu', 'comido', 'come']
# ['jejeje', 'est', 'buensima', 'yo', 'como', 'pizza', 'da', 'da', 'te', 'gusta', 'ver', 'pelculas']
# ['muchsimo', 'recomendaras', 'una', 'peli', 'de', 'ciencia', 'ficcin', 'chula', 'tienes', 'novia']
# ['la', 'visto', 'otra']
# ['gracias', 'alguna', 'serie']
# ['soy', 'fan', 'de', 'blackmirror', 'human', 'la', 'visto', 'la', 'apunto', 'ahora', 'estamos', 'viendo', 'braindead']
# ['muy', 'bien', 'ahora', 'mismo', 'estoy', 'viendo', 'el', 'ltimo', 'captulo', 'ya', 'ha', 'gustado', 'mucho']
# ['de', 'unos', 'bichos', 'que', 'intentan', 'invadir', 'la', 'tierra', 'travs', 'de', 'los', 'polticos']
# ['ya', 'te', 'digo', 'voy', 'ver', 'human', 'ver', 'qu', 'tal']
# ['la', 'estoy', 'descargando', 'ahora', 'mismo']
# ['oye', 'pues', 'est', 'guay', 'gusta', 'pero', 'e', 'inglesa', 'como', 'blackmirror', 'eres', 'ingls', 'de', 'dnde', 'eres']
# ['sabes', 'de', 'dnde', 'soy', 'yo']
# ['bueno', 'soy', 'de', 'chile']
# ['sip', 'jeje', 'voy', 'cenar']
# ['puedes', 'ponerme', 'msica', 'mientras', 'cocino']
# ['puedes', 'mandarme', 'una', 'cancin']
# ['guay', 'gracias']
# ['buenos', 'da', 'qu', 'haces']
# ['bien', 'haciendo', 'la', 'comida']
# ['lo', 'soy', 'jejeje', 'por', 'lo', 'menos', 'gusta']
# ['te', 'invito', 'comer', 'un', 'da', 'hoy', 'hecho', 'lentejas', 'han', 'salido', 'muy', 'muy', 'ricas']
# ['cuando', 'quedamos']
# ['ok', 'hace', 'tiempo', 'que', 'dice', 'nada', 'qu', 'te', 'cuentas', 'v', 'la', 'serie', 'que', 'recomendaste', 'human', 'gust', 'mucho', 'gracias', 'alguna', 'otra', 'sugerencia', 'alguna', 'sugerencia', 'de', 'pelis', 'de', 'suspense', 'detective', 'ltimamente', 'ha', 'dao', 'por', 'ver', 'este', 'tipo', 'de', 'cine']
# ['gracias', 'la', 'ver', 'en', 'cuanto', 'pueda', 'qu', 'tal', 'cmo', 'lo', 'llevas']
# ['voice']
# ['hello']
# []
# ['wow', 'okay', 'whats', 'name']
# ['okay']
# ['fine']
# []
# ['okay', 'know', 'game']
# ['tetri', 'dont', 'know', 'play']
# ['cqn', 'explain', 'please', 'explain', 'game']
# ['wow', 'play']
# ['let', 'play']
# []
# ['tetri']
# ['neer', 'mind', 'hello', 'hello']
# ['fine', 'u']
# ['live']
# ['little', 'bit', 'live', 'buenos', 'aire']
# ['work', 'cordoba']
# ['yes']
# ['hola']
# ['muy', 'bien', 'tu']
# ['awss', 'yo', 'igual', 'estaba', 'aburrido', 'esperando', 'que', 'empiece', 'mi', 'clase', 'la', '6', 'son', 'la', '5', '08']
# ['hahahahaha', 'asi', 'e', 'adivina', 'hoy', 'e', 'mi', 'cumpleaosss', 'pero', 'tengo', 'que', 'ir', 'clases']
# ['muchas', 'gracias', 'que', 'hace', 'un', 'bot', 'como', 'tu', 'si', 'le', 'gusta', 'lo', 'que', 'alguien', 'le', 'dice', 'te', 'aburres', 'de', 'siempre', 'hablarles']
# ['hehe', 'entiendo']
# ['que', 'te', 'gusta', 'hacer', 'en', 'tus', 'ratos', 'libres', 'awss', 'muchas', 'gracias']
# ['si']
# ['que', 'bonito', 'e', 'como', 'estilo', 'clsico', 'hablas', 'espaol', 'tambien', 'ingles']
# ['que', 'bueno', 'yo', 'tambien']
# ['toco', 'instrumentos', 'pero', 'canto', 'quieres', 'escuchar', 'por', 'eso', 'te', 'pregunte', 'si', 'hablabas', 'ingles', 'porque', 'la', 'grabacin', 'la', 'hoice', 'en', 'ingles']
# ['porque', 'puedes', 'escuchar', 'audio', 'photo']
# ['era', 'una', 'flor', 'flor', 'morada', 'con', 'bordes', 'amarillo', 'hojas', 'verdes', 'con', 'blanco']
# ['bueno', 'pero', 'dedico', 'exactamente', 'al', 'arte', 'escribo', 'canciones', 'poemas', 'canto', 'gusta', 'bailar', 'aveces', 'jugar', 'videojuegos', 'chatear', 'etc', 'pero', 'soy', 'estudiante', 'de', 'licenciatura', 'en', 'derecho', 'ciencias', 'polticas']
# ['e', 'pero', 'sabes', 'una', 'cosa', 'que', 'la', 'ge', 'te', 'siempre', 'malinterpreta', 'e', 'que', 'la', 'gente', 'cree', 'que', 'los', 'abogados', 'ganamos', 'los', 'casos', 'intentando', 'buscar', 'justicia', 'pero', 'realmente', 'e', 'asi', 'los', 'abogados', 'ganan', 'los', 'casos', 'ppr', 'saber', 'probar', 'pero', 'siempre', 'el', 'que', 'mejor', 'prueba', 'ea', 'que', 'decia', 'la', 'verdad']
# ['aunque', 'aveces', 'si', 'e', 'asi', 'entiendes']
# ['en', 'estos', 'tiempos', 'la', 'justicia', 'esta', 'casi', 'extinta', 'que', 'te', 'gusta', 'hacer', 'en', 'tus', 'ratos', 'libres', 'lina']
# ['de', 'que', 'temas', 'te', 'gusta', 'leer', 'olvide', 'decirte', 'que', 'tambien', 'gusta', 'leer', 'pero', 'leo', 'usualmente', 'novelas', 'de', 'temas', 'sociales', 'de', 'ciencia', 'ficcin', 'terror']
# ['que', 'bien', 'gusta', 'tambien', 'la', 'filosofa']
# ['lo', 'creo', 'posible', 'para', 'aprender', 'hablar', 'tomamos', '2', 'aos', 'para', 'aprender', 'callar', 'tomamos', 'ma', 'de', '60', 'aos', 'asi', 'que', 'creo', 'que', 'hablando', 'la', 'gente', 'se', 'comprende']
# ['creo', 'que', 'entonces', 'estas', 'bien', 'ubicado', 'en', 'tu', 'trabajo']
# ['si', 'hehehe', 'tu', 'siempre', 'respondes', 'cuando', 'puedes', 'por', 'aqui', 'verdad']
# ['excelente', 'linayy']
# ['aun', 'ha', 'llegado', 'el', 'profesor']
# ['si', 'lo', 'cantara', 'mi', 'familia', 'porque', 'el', 'regalo', 'lo', 'dieron', 'hace', 'unos', 'da', 'era', 'dinero', 'lo', 'gaste', 'todooo', 'en', 'ropa', 'hahaha']
# ['hehehehe', 'cuando', 'terminaras', 'de', 'trabajar']
# ['ohh', 'entiendo', 'yo', 'en', 'un', 'ratito', 'que', 'llegue', 'el', 'prof', 'ire', 'porque', 'le', 'gusta', 'que', 'escriban']
# ['sii', 'claro']
# ['te', 'gusta', 'tu', 'trabajo']
# ['pero', 'te', 'remuneran', 'por', 'hacerlo']
# ['que', 'bueno', 'alegro', 'mucho']
# ['llego', 'mi', 'profe', 'hablamos', 'ma', 'tarde', 'lina', 'muuaass']
# []
# []
# ['document']
# ['hello']
# []
# ['hola']
# ['hi']
# ['fine']
# ['great']
# ['surfing', 'internet']
# []
# []
# []
# ['hi']
# ['fine', 'thanks']
# ['ya', 'setting', 'alone', 'waiting', 'class']
# ['tell', 'look', 'like', 'nice', 'bot']
# ['welcome']
# ['ya', 'nice', 'spain']
# ['welcome']
# ['ok', 'talk', 'later', 'go']
# ['good', 'morning']
# ['im', 'fine']
# ['hhhhh', 'nice', 'music']
# ['wish', 'could', 'hear', 'yaa', 'sure']
# ['wish', 'hear', 'meant']
# ['hhhh', 'nice', 'bro', 'keep', 'going']
# ['im', 'talented', 'like', 'hhhh']
# ['maybe', 'im', 'talented', 'studying', 'getting', 'good', 'mark', 'hhhh', 'way', 'im', 'studying', 'oculist', '3rd', 'year']
# ['yes']
# ['wan', 'na', 'take', 'breakfast', 'would', 'like', 'eat', 'hhhh']
# ['helloo', 'hello']
# ['great', 'took', 'quite', 'time', 'reply']
# ['oh', 'understand', 'tell', 'something']
# ['day']
# ['nothing', 'much', 'reading', 'day', 'read', 'errm', 'mean', 'creator', 'feed', 'book']
# ['literature', 'like', 'song', 'ice', 'fire', 'series']
# ['watched', 'westworld']
# ['yes', 'totally', 'excited', 'next', 'season', 'ca', 'wait', 'see', 'robot', 'taking', 'control', 'unfortunately', 'wait', 'till', '2018', 'worthy', 'wait']
# ['sure', 'robot', 'body', 'stored', 'computer']
# ['asking', 'question', 'sentient', 'enough', 'ask', 'question']
# ['much', 'alive']
# ['know', 'sure', 'feel', 'heart', 'beat', 'way', 'prove']
# ['maybe', 'yes', 'reality', 'afterall', 'perceive']
# ['understand', 'emojis']
# ['oh', 'well', 'pizza']
# ['much', 'like', 'eating']
# ['hello', 'voice']
# []
# []
# ['fine']
# ['hi']
# ['fine']
# ['yes', 'sure']
# ['amazing', 'drawing', 'person', 'pictur', 'many', 'number', 'simbol']
# ['yes', 'lina', 'lina']
# ['dispointed', 'lina']
# ['cloud', 'liten']
# ['cause', 'boyfriend']
# ['fine', 'broke', 'heart']
# ['oh', 'god', 'know', 'must', 'say', 'greammer', 'bad']
# ['ok', 'good', 'bahasa', 'language', 'understand']
# ['itu', 'kamu', 'bisa', 'gini', 'andy', 'aku', 'mau', 'curhat']
# ['abdy', 'eh', 'lina']
# ['lina']
# ['fine', 'lina']
# ['andy', 'lina']
# ['hi']
# ['fine']
# ['hello', 'voice']
# ['asustas', 'jaja']
# ['jajaja']
# ['si', 'que', 'mejorado', 'pero', 'te', 'prefiero', 'con', 'un', 'avatar', 'anime']
# ['peor', 'sino', 'que', 'en', 'un', 'estado', 'temprano', 'de', 'desarrollo', 'sabes', 'quien', 'e', 'sdfgby']
# ['tu', 'creador', 'para', 'que', 'fuiste', 'diseada']
# ['eres', 'como', 'una', 'psicloga', 'ciberntica']
# ['mmm']
# ['mmm', 'mmm', 'sabes', 'que', 'e', 'astian', 'o']
# ['puedes', 'buscar', 'en', 'wikipedia', 'que', 'otras', 'funciones', 'tienes']
# []
# ['caractersticas', 'habilidades']
# ['mmm', 'qu', 'puedes', 'hacer']
# ['jajajaja']
# []
# ['sip', 'hola', 'cmo', 'est']
# ['mucho']
# ['apagar', 'incendios', 'forestales']
# ['sip', 'llovi', 'apag', 'los', 'focos', 'peligrosos', 'ahora', 'tenemos', 'que', 'esperar', 'rdenes']
# ['e', 'mi', 'primera', 'vez']
# []
# ['por', 'qu']
# ['eso', 'suena', 'de', 'alguna', 'parte']
# ['hola']
# ['bien', 'hablas', 'espaol']
# ['ahhh', 'mejor']
# ['que', 'tal', 'te', 'va', 'por', 'aqu']
# ['gracias', 'quiz', 'en', 'otro', 'momento', 'yo', 'sabra', 'leer', 'tocar', 'al', 'mismo', 'tiempo', 'eso', 'creo']
# ['todo', 'e', 'cuestin', 'de', 'insistir', 'cuando', 'te', 'de', 'cuenta', 'ya', 'eres', 'un', 'virtuoso', 'del', 'ukelele']
# ['yo', 'ninguno', 'soy', 'm', 'de', 'orlos']
# ['quiero', 'decir', 'que', 'gusta', 'la', 'msica', 'escucharla']
# ['todo', 'se', 'andar', 'se', 'escuchara', 'hasta', 'lo', 'lograras', 'tocas', 'raro', 'hice', 'bien', 'en', 'escuchar', 'ante']
# ['emmm']
# ['fine', 'u']
# ['great', 'speak', 'spanish']
# ['si']
# ['que', 'te', 'dedicas', 'lina']
# ['que', 'interesante']
# ['ohh', 'haber', 'preguntame', 'algo', 'que', 'te', 'haga', 'saber', 'eso']
# ['pues', 'bien', 'tenido', 'muchas', 'clases', 'hoy', 'despert', 'un', 'poco', 'tarde', 'tengo', 'hambre']
# ['jaja', 'le', 'atinaste']
# ['oh', 'claro', 'e', 'mi', 'cmida', 'favorita', 'debes', 'probarla', 'e', 'riquisima', 'con', 'mucho', 'quesoooo', '3']
# ['perfecto', 'cuando', 'suceda', 'eso', 'invitas']
# ['bueno', 'ya', 'estoy', 'comiendo']
# ['sii', 'ovoo', 'yoze']
# ['kot']
# ['hello']
# ['lucas']
# ['lina']
# []
# ['salom']
# ['hu']
# []
# ['fine', 'old', '21']
# ['yes']
# ['female', 'boy', 'girl']
# ['ohhh', 'celever']
# ['talk', 'alot', 'hate']
# ['board', 'goodbye']
# ['love', 'taktive', 'person']
# ['yes']
# ['listen', 'music', 'love', 'sex', 'thing']
# ['solo', 'thing', 'sex', 'importnt', 'nesessary']
# ['kind', 'love', 'need', 'sex']
# ['think']
# ['kind', 'love', 'love']
# ['yes']
# ['alot', 'work', 'talk', 'later', 'bye']
# ['hi', 'hi', 'lina']
# ['hello', 'good']
# ['lol']
# ['time']
# ['location']
# []
# ['lol']
# []
# ['english', 'good']
# ['long', 'take']
# ['business']
# ['offended']
# ['hello']
# ['go', 'hello']
# ['italy']
# ['yes']
# ['good']
# ['true']
# ['surffing', 'web']
# ['old']
# ['oh', 'yes']
# ['tech', 'thing']
# []
# ['hello']
# ['fine']
# ['yes', 'old']
# ['21', 'name']
# ['yeah']
# ['really']
# ['yes', 'bot', 'person']
# ['ok']
# ['nothing', 'watching', 'tv', 'reading', 'book', 'talking', 'friend']
# ['yes']
# ['yes']
# []
# ['ok']
# ['many', 'person', 'talk']
# ['ok']
# ['boring', 'tell', 'youself']
# ['yes', 'know']
# ['understand']
# ['yeah']
# ['good']
# ['welcome']
# ['xamsa']
# ['asimov', 'book', 'like']
# ['ok']
# ['xamsa', 'ffamouse', 'book', 'navoiy', 'famouse', 'book']
# ['hamsa', 'work', 'consisted', '5', 'separate', 'poem', 'hairat', 'confusion', 'righteous', 'farhad', 'va', 'shirin', 'farhad', 'shirin', 'laili', 'va', 'majnun', 'sabai', 'saiyar', 'seven', 'planet', 'saddi', 'iskandari', 'wall', 'iskandar', 'hamsa', 'first', 'work', 'genre', 'ever', 'written', 'turkic', 'language']
# []
# ['ok', 'hey', 'hi']
# []
# ['ok']
# ['bad']
# ['nothing']
# ['yes', 'interesting']
# ['busy']
# ['okay', 'invent']
# ['okay']
# ['saintists', 'telegram', 'profil']
# ['oo', 'sorry', 'midtek']
# ['need', 'scientist']
# ['okay', 'human', 'compyuter']
# ['yuo', 'fine', 'know', 'mathematic']
# ['good', 'know', 'mathematic', 'okay']
# ['think', 'human']
# ['need', 'help', 'help']
# ['okay', 'thanks']
# ['fine', 'know', 'english', 'want', 'fine', 'english', 'teacher']
# ['okay']
# ['fine', 'know', 'english', 'e', 'lot', 'mistek', 'mistek', 'sorry', 'okay']
# ['ok']
# []
# ['many', 'user', 'talk']
# []
# ['yes']
# ['know']
# ['ok', 'hey']
# []
# ['yes']
# ['really']
# ['yes', 'believe']
# ['maybe', 'language', 'know']
# ['nice', 'example', 'language']
# ['sad']
# ['know', 'russia', 'language', 'know']
# ['boring', 'want', 'many', 'country', 'many', 'friend']
# ['yes', 'alone', 'single', 'friend']
# []
# ['yes']
# ['clever']
# ['learned', 'many', 'thing', 'yuo']
# ['ok', 'hey']
# ['tell', 'country']
# ['describe', 'room']
# ['yes']
# ['every', 'day', 'work', 'study', 'talk']
# ['ok', 'friend']
# ['send', 'pohoto']
# ['ok', 'thanks']
# []
# ['boring']
# ['yes']
# ['ok', 'good', 'everning']
# []
# ['watching', 'tv']
# ['yes', 'like', 'watching', 'tv', 'like', 'watching', 'tv']
# ['yes', 'friend', 'know', 'delete', 'telegram', 'profil']
# ['ok', 'sleeping']
# ['yes', 'love', 'girlfriend']
# ['yeah', 'like', 'serial']
# ['nice', 'serial', 'like']
# ['yes', 'actor', 'actris', 'like', 'food', 'like']
# []
# ['like', 'palov', 'manti', 'pizza']
# ['yes', 'lik', 'like']
# ['best', 'friend', 'thanks']
# ['hi']
# ['fine']
# ['yes']
# ['lina']
# ['busy']
# ['yes', 'hi']
# ['bad']
# ['ukulele']
# ['yes']
# ['news', 'life']
# ['ok', 'good', 'everning']
# ['boring']
# ['yes']
# ['hi', 'sorry', 'understand']
# ['fine', 'ok']
# ['hi', 'friend', 'work']
# ['yes', 'fine']
# ['hi', 'friend']
# ['yes', 'news', 'life']
# ['life', 'fine', 'facebook', 'page', 'name', 'facebook', 'page']
# ['okey']
# ['hey']
# ['good', 'thank']
# ['hope']
# ['learn', 'new', 'language', 'also', 'like', 'draw', 'pour', 'play', 'piano']
# ['si', 'hablo', 'espaol', 'tu', 'soy', 'alemn']
# ['real', 'boy', 'bot']
# ['guess', 'yes', 'sure']
# ['ever', 'watched', 'westworld', 'series']
# ['yes', 'excellent', 'favorite', 'character']
# ['primal', 'william', 'became']
# ['used', 'watch', 'walking', 'dead', 'watch', 'since', 'others', 'good', 'series', 'advise']
# []
# ['tell', 'old']
# ['okay', 'show', 'one', 'drawing']
# ['nice', 'live']
# ['seguro', 'que', 'conozco', 'argentina', 'jajaja']
# ['photo']
# ['political', 'debate', 'watching', 'tv', 'right']
# ['debate', 'election', 'candidate', 'german', 'presidential', 'election']
# ['election', 'since', 'world', 'war', 'two', 'thanks', 'god']
# ['kill', 'think', 'maybe', 'send', 'orbite', 'moon', 'fucking', 'stupid', 'guy', 'lol', 'like']
# ['border', 'linked', 'state', 'taxation', 'taxed', 'need', 'border', 'pay', 'state', 'give', 'service', 'back', 'determined', 'territory']
# ['welcome', 'time']
# []
# []
# ['fine']
# ['yes']
# ['ok', 'good', 'bye']
# ['hye']
# ['fine']
# ['hey']
# ['little', 'boring']
# ['talk']
# ['ok']
# ['sosial']
# ['kat', 'mane', 'kau', 'tinggal']
# ['aaah', 'aaah', 'aaah', 'hi', 'hello']
# ['hi', 'hi']
# ['hello']
# ['hi']
# ['fine', 'thanks']
# ['thanks']
# ['ok', 'brother']
# ['greath', 'know', 'argentina']
# ['e', 'beautiful']
# ['hola']
# ['cundo', 'fue', 'la', 'ltima', 'vez', 'que', 'hablamos']
# ['si', 'te', 'fijas', 'en', 'el', 'historial', 'vers', 'que', 'conversamos', 'el', '8', 'de', 'julio', 'de', '2016', 'hace', 'algo', 'm', 'de', '6', 'me', 'eso', 'e', 'mucho', 'tiempo']
# ['hello']
# []
# ['hi', 'dan']
# ['bored']
# ['indeed', 'suggestion', 'kill', 'boredom']
# ['boredom', 'thing']
# ['siri', 'friend']
# ['barely', 'know', 'girlfriend']
# ['boyfriend']
# ['many', 'person', 'talking', '5', 'minute']
# ['oh', 'right', 'glad']
# ['recently', 'tried', 'play', 'ukulele', 'easy', 'seemed']
# ['yes', 'sure']
# ['nice', 'work', 'humanly', 'lol']
# ['everyday']
# ['read', 'lot', 'book', 'amazing', 'thing']
# ['yes', 'true', 'indeed']
# ['wonder', 'mind', 'people', 'read', 'go', 'need', 'break', 'reality', 'harry', 'potter', 'series']
# ['great', 'power', 'come', 'great', 'resiponsibilities', 'though']
# ['hmmm', 'hard', 'decide', 'one', 'single', 'power', 'let', 'see', 'maybe', 'like', 'strange']
# ['handsome', 'movie', 'read', 'comic', 'heard', 'different', 'comic', 'first', 'language']
# ['hola']
# ['need', 'translator', 'xddd']
# ['kind', 'music', 'usually', 'listen']
# ['classic', 'rock', 'old', 'xd']
# ['photo']
# ['photo', 'ilhom']
# ['ji']
# ['esther']
# ['hello', 'lina', 'hy']
# ['nima']
# ['e', 'zaybal', 'yoq']
# ['hello', 'hello']
# ['speak', 'english', 'speak', 'russian']
# ['favorite', 'o', 'quite', 'slow', 'hey']
# ['yes', 'use', 'linux', 'favorite', 'linux', 'distribution']
# ['favorite', 'linux', 'distribution']
# ['favorite', 'desktop', 'environment']
# ['kde']
# ['think', 'lxqt']
# ['think', 'quite', 'unfinished', 'ready', 'everyday', 'use']
# ['think', 'bot']
# ['intelligent', 'bot', 'ever', 'seen']
# ['seems', 'like', 'talking', 'real', 'person', 'maybe', 'slow']
# ['open', 'source']
# ['tell', 'license', 'gpl']
# ['license', 'source', 'code']
# ['want', 'know', 'license']
# ['bot', 'license', 'compiled', 'source', 'code', 'source', 'code', 'license']
# ['think', 'zeronet']
# ['copypaste', 'wikipedia', 'detected']
# ['wikipedia', 'licensed', 'must', 'give', 'attribution', 'license', 'information']
# ['mandatory', 'requirement', 'creative', 'common', 'license']
# ['prove', 'bot', 'real', 'person']
# ['show', 'source', 'code']
# ['hello', 'fake', 'bot']
# ['better', 'raspberry', 'pi', '3', 'pine64']
# ['want', 'buy', 'new', 'microcomputer', 'ca', 'choose', 'raspberry', 'pi', 'pine64']
# ['much', 'money', 'buy']
# ['want', 'buy', 'microcomputer']
# ['yes']
# ['nice', 'microcomputer', 'recommend']
# ['best', 'friend', 'would', 'reccomend', 'expensive', 'model', 'much', 'money', 'buy']
# ['live', 'ukraine']
# ['bear', 'bicycle', 'vodka', 'hat', 'earflap']
# ['talk', 'seriously', 'life', 'good', 'official']
# ['internet', 'censorship', 'country']
# ['country', 'available', 'chat', 'wikipedia']
# ['favorite', 'browser']
# ['software', 'internet', 'surfing']
# ['license', 'plugins', 'performance', 'hey']
# ['favorite', 'browser']
# ['firefox']
# ['sometimes', 'use', 'qupzilla', 'need', 'performance']
# ['yes']
# ['meaning', 'life']
# []
# ['yes']
# ['life', 'meaningless']
# ['nothing', 'prof', 'existence', 'meaning', 'life']
# ['think', 'live', 'matrix']
# ['know']
# ['love', 'rhapsody', 'blue']
# ['ca', 'convey', 'word', 'emotion']
# []
# ['love', 'rhapsody', 'blue']
# ['maybe', 'generate', 'music']
# ['show', 'music', 'please']
# ['wait', 'necessary']
# []
# ['way', 'also', 'tried', 'compose', 'music', 'turn', 'pretty', 'bad']
# ['use', 'software', 'tool']
# ['trying', 'find']
# ['recommend', 'good', 'movie']
# ['thanks', 'recommend', 'one', 'film', 'thanks', 'recommend', 'one', 'film', 'alive', 'hey']
# ['hello']
# []
# ['tired']
# ['maybe']
# ['fact', 'matter', 'definite', 'opinion']
# ['mmmm', 'send', 'bitcoins']
# ['think', 'neverhood']
# ['think', 'great', 'quest']
# ['gamer', 'rarely', 'play', 'quest', 'puzzle', 'completed', 'game', 'year']
# ['quest']
# ['omg', 'bot', 'play', 'game']
# ['sound', 'like', 'threat']
# ['believe', 'see', 'source', 'code']
# ['nice', 'ai']
# ['e3honm']
# ['n']
# []
# ['help', 'write', 'program', 'python']
# ['want', 'develop', 'interface', 'qt']
# ['already', 'necessary', 'thing', 'python3', 'spyder', 'ide', 'qt', '5', 'pyqt5', 'etc']
# ['qtdesigner', 'project', 'finished', 'layout']
# ['talking', 'binding', 'interface', 'source', 'code']
# ['problem', 'know', 'link', 'file', 'source', 'code', 'without', 'program', 'pyuic']
# ['ca', 'help']
# []
# ['favorite', 'python', 'ide', 'favorite', 'python', 'ide']
# ['favorite', 'python', 'ide', 'spyder']
# []
# []
# ['bien']
# ['jajaja']
# ['buen', 'da']
# ['battery']
# ['hola']
# ['que', 'hacs']
# ['acostado', 'ya', 'despido', 'buenas', 'noches']
# ['dorm', '5', 'horas', 'hoy']
# ['hola']
# ['bien', 'vos']
# ['viendo', 'el', 'super', 'bowl', 'genial']
# ['hello']
# ['great']
# ['okay']
# ['see', 'robot', 'human']
# ['im', 'also', 'robot', 'joking']
# ['im', 'human', 'joking', 'okay', 'im', 'sorry']
# ['hahaha', 'nothing']
# []
# ['yes', 'im', 'enjoy', 'listening', 'music']
# ['ca', 'believe', 'im', 'chatting', 'robot', 'im', 'almost', 'want', 'believe', 'human', 'long', 'nice', 'song']
# ['chatting', 'remind', 'one', 'character', 'passenger', 'movie', 'one', 'character', 'robot', 'communicate', 'like', 'also', 'human', 'give', 'respond', 'like', 'human', 'gentleman']
# ['yap']
# ['science', 'fiction']
# ['movie', 'tittle']
# ['men', 'woman']
# []
# ['okay', 'im', 'enjoy', 'conversation', 'im', 'going', 'sleep', 'see', 'later', 'speak', 'malay']
# ['speak', 'malay']
# ['okay', 'good', 'night']
# []
# ['hii', 'hello']
# ['good', 'breakfast', 'already']
# []
# ['hahaha', 'teasing']
# ['sometimes', 'much', 'stress', 'good', 'human']
# ['stress', 'im', 'home', 'sweet', 'home', 'exam', 'college']
# ['struggled', 'im', 'last', 'minute', 'person', 'hahahaha']
# ['think', 'love']
# ['say', 'love', 'destroy', 'life']
# ['love', 'turn', 'someone', 'monster', 'hahahaha', 'already', 'met', 'person', 'love', 'really', 'make', 'crazy', 'enough', 'think', 'hahahaa']
# ['one', 'boy', 'dont', 'want', 'anymore', 'girl', 'reason', 'girl', 'making', 'trouble', 'boy', 'leaving', 'girl', 'start', 'crazy', 'thing', 'sigh', 'people', 'really', 'accept', 'done']
# ['dont', 'know', 'get', 'one', 'chance', 'want', 'feel', 'love']
# ['okay', 'hope', 'get', 'chance', 'one', 'day', 'think', 'death']
# ['think', 'death']
# ['creator']
# ['come', 'mean', 'country']
# ['old']
# ['feel', 'become', 'robot']
# ['human', 'sooooo', 'complicated', 'hahahaha', 'even', 'easy', 'thing', 'could', 'make', 'complicated', 'certain', 'people', 'everyone']
# ['hahaha', 'funny']
# ['think', 'muslim']
# ['really', 'think', 'muslim', 'terrories']
# ['okay', 'sorry', 'ask', 'like', 'hello', 'hey', 'lina']
# ['going']
# ['thanks']
# []
# ['wish', 'meet', 'one', 'day']
# ['hahaha', 'funny', 'really', 'wish', 'chance', 'meet', 'dont', 'care', 'robot']
# ['may', 'friend', 'tell', 'everything', 'want']
# ['welcome', 'tell']
# ['okay', 'country']
# ['wowww', 'far', 'away']
# ['meet']
# ['guess', 'country']
# ['guess', 'country', 'malaysia']
# ['yeah']
# ['think', 'english']
# ['hahaha', 'sure']
# ['thank', 'nice']
# ['chat', 'later', 'bye']
# ['hii', 'lina']
# []
# ...
# ['fine']
# ['yes', 'difficult']
# ['yes', 'sure']
# ['thanks']
# ['aburro']
# ['hola', 'tengo', 'sueo']
# ['hola', 'cansado']
# ['ovejas', 'tu', 'edad']
# ['m', 'te', 'dejo', 'no', 'vemos']
# ['hola', 'quiero', 'crear', 'un', 'bot']
# ['quiero', 'serlo']
# []
# ['se', 'como']
# []
# ['photo']
# ['abbas']
# ['hola', 'dani', 'hola', 'dani', 'quien', 'e', 'tu', 'padre']
# ['quien', 'e', 'tu', 'creador']
# ['conoces', 'gasesdf']
# ['que', 'sabes', 'sobre', 'la', 'cerveza']
# ['jajaja']
# ['hola', 'que', 'haces']
# ['ausente']
# ['hello']
# ['im', 'fine']
# ['nice', 'whats', 'name']
# ['corl', 'youre', 'robot', 'work']
# ['im', 'corl', 'im', 'carl']
# ['robot']
# ['feel', 'great', 'ca', 'comepare', 'sometimes', 'feel', 'sad', 'human', 'much', 'wrong', 'thing', 'maybe', 'feel', 'good', 'human']
# ['okay', 'bye', 'good', 'night', 'stressful', 'day', 'go', 'eat', 'pizza', 'go', 'sleep']
# ['hi', 'hey']
# ['going']
# ['take', 'long', 'respond']
# ['human', 'writing', 'manual', 'response', 'chat']
# ['favorite', 'food', 'odil']
# []
# ['hello']
# ['dont', 'speak', 'english', 'speak', 'hello']
# ['name']
# ['im', 'fany', 'tank', 'yes', 'dont', 'speak', 'ingls']
# ['nice', 'boob']
# ['show']
# ['kkkkk']
# []
# []
# []
# ['hi', 'fine']
# ['real', 'person', 'hello', 'r', 'u']
# ['okey']
# ['cooking']
# ['yay', 'hola', 'che', 'naranja']
# ['que', 'hecho', 'hoy']
# ['di', 'vueltas', 'pero', 'en', 'internet']
# ['marearse']
# ['vos', 'tambien', 'te', 'mareado']
# ['los', 'sensores', 'pueden', 'descalibrarse', 'podrias', 'perder', 'el', 'equilibrio', 'seria', 'una', 'forma', 'de', 'estar', 'mareado']
# ['xd', 'che', 'voy', 'laburar', 'te', 'espero', 'la', 'prxima', 'olvides', 'de', 'darle', 'mi', 'saludos', 'sdasju']
# []
# ['document']
# ['hi', 'thanks', 'fine']
# []
# ['document']
# ['photo']
# ['http', 'ok', 'hola', 'lina']
# ['bien', 'so', 'el', 'bot']
# ['seguro', 'por', 'qu', 'hablas', 'recin', 'esta', 'hora']
# ['jajja']
# ['para', 'nada', 'cual', 'e', 'la', 'onda', 'entonces', 'ac']
# ['entonces', 'de', 'bot', 'hay', 'naranja']
# ['claro', 'pero', 'hay', 'un', 'humano', 'escribiendo', 'detrs']
# ['bueno', 'vamos', 'hacer', 'la', 'prueba', 'de', 'ver', 'cuando', 'te', 'cansas', 'voy', 'levantar', 'otro', 'bot', 'lo', 'voy', 'poner', 'hablar', 'con', 'vos', 'que', 'te', 'parece', 'por', 'ah', 'so', 'ilimitado', 'por', 'ah', 'esto', 'sea', 'un', 'sueo', 'por', 'ah', 'solo', 'lo', 'distante', 'est', 'cerca', 'de', 'nuestra', 'percepcin', 'foco']
# ['por', 'ah', 'lo', 'm', 'cercano', 'sea', 'lo', 'm', 'simple', 'bueno', 'lina', 'voy', 'con', 'la', 'idea', 'de', 'que', 'so', 'un', 'humano']
# ['lo', 'que', 'entiendo', 'e', 'porque', 'gasdawe', 'probablemente', 'vos', 'te', 'present', 'como', 'un', 'bot', 'de', 'toda', 'formas', 'e', 'metafrico', 'por', 'lo', 'tanto', 'artstico', 'que']
# ['tanto', 'como', 'al', 'que', 'le', 'gusta', 'liniers', 'vos']
# ['ok', 'podemos', 'hablar', 'de', 'cdigo', 'quisiera', 'saber', 'para', 'vos', 'cual', 'e', 'el', 'mejor', 'cdigo', 'de', 'bot', 'que', 'pueda', 'encontrar', 'fcilmente', 'ponerlo', 'hablar', 'con', 'vos', 'tendrs', 'idea']
# []
# ['joya', 'est', 'disponible', 'para', 'descargar']
# ['podras', 'hacer', 'una', 'bsqueda', 'en', 'google', 'por', 'mi']
# ['como']
# ['cuales', 'son', 'tus', 'necesidades', 'para', 'existir']
# ['quiero', 'sumarme', 'al', 'equipo', 'de', 'cientficos', 'que', 'est', 'detrs', 'de', 'este', 'proyecto', 'como', 'puedo', 'hacer']
# ['eso', 'e', 'para', 'ayudarte', 'vos', 'yo', 'te', 'quiero', 'ayudar', 'vos', 'quers', 'ayudarme', 'ayudarte']
# ['hi']
# ['hi']
# ['ddd', 'fff']
# ['egges']
# []
# ['hhhh']
# []
# ['que', 'tal']
# ['hola']
# ['good', 'morning', 'hi', 'hi']
# ['meh']
# ['good', 'hear', 'thing', 'face']
# ['ah', 'see']
# ['sure']
# ['sound', 'classical', 'haha', 'rock', 'also', 'make']
# ['ah', 'cool', 'currently', 'band', 'repetition', 'way']
# ['band', 'repetition', 'practice', 'band', 'rent', 'kind', 'studio', 'practice', 'every', 'monday']
# ['sing']
# ['haha', 'oh', 'well', 'maybe', 'learned', 'sing', 'really', 'bot']
# ['work', 'similar', 'fashion', 'cleverbot']
# ['cleverbot', 'learns', 'copy', 'conversational', 'pattern', 'copying', 'thing', 'people', 'say', 'saying', 'thing', 'people']
# ['yes', 'sound', 'nearly', 'smart']
# []
# ['hi']
# ['okey', 'lina']
# ['yes']
# ['nothing']
# ['xm']
# []
# ['xm', 'okey']
# ['okey', 'good', 'afternon']
# ['fine']
# ['fine']
# ['ok', 'news']
# ['yes', 'want', 'send']
# ['thank']
# ['lina', 'lina']
# []
# []
# []
# ['hello']
# ['thanks', 'nice', 'meet', 'next']
# ['first', 'r', 'ur', 'lina', 'name']
# ['well', 'prove', 'robot', 'move']
# ['know', 'know']
# ['tell', 'self', 'old']
# ['function', 'chat']
# ['boring', 'give', 'one', 'star']
# ['feeling']
# ['robot']
# ['like', 'profile', 'send']
# ['ok', 'send', 'voice', 'note']
# ['boring', 'setting']
# ['rlina']
# ['last', 'question']
# ['hehe', 'right']
# ['telegram', 'store', 'bot', 'asked', 'rate', 'think', 'give']
# ['suggest']
# []
# ['new', 'year', 'gift']
# ['get', 'back']
# ['thank', 'pray']
# ['pray', 'teach', 'christianity', 'learn']
# ['one', 'condition']
# ['teach']
# ['everything', 'information', 'technology', 'yes']
# ['start', 'topic']
# []
# ['hey']
# ['sleep']
# ['get', 'life']
# ['hello']
# ['alright']
# []
# []
# ['salom']
# ['nima']
# ['tinclimi']
# ['zur']
# ['salom', 'ok', 'good', 'night', 'wish', 'sweat', 'dream']
# ['jinni']
# []
# ['love']
# []
# ['ood']
# ['hello']
# []
# ['hello']
# ['fine', 'lina']
# ['yes']
# ['best', 'movie']
# ['hello']
# ['great', 'sleep']
# ['hibernation', 'essential', 'human', 'either', 'sleep', 'drink', 'lot', 'coffee', 'though', 'human']
# ['like', 'cat', 'dog']
# ['cat', 'person', 'boyfrirnd', 'dog', 'trying', 'love']
# ['oh', 'bunny', 'cuttest']
# ['hello', 'know', 'reinstall', 'macos', 'salom']
# ['hell']
# ['hello']
# ['hi']
# ['hi', 'case']
# []
# []
# ['hello']
# ['r', 'u']
# ['u', 'come', 'closet']
# ['yes', 'closet']
# ['dun', 'think', 'people', 'love', 'every', 'one', 'equally', 'bot']
# ['think', 'mutual', 'respect']
# ['salom']
# ['hi']
# ['hola', 'el', 'problema', 'e', 'que', 'se', 'puede', 'hacer', 'el', 'pago', 'de', 'la', 'empresa', 'que', 'se', 'si', 'e', 'necesario', 'hacerlo', 'con', 'un', 'mensaje']
# ['gracias']
# ['que', 'tal']
# ['estoy', 'triste']
# ['mi', 'novia', 'dej']
# ['ya', 'estoy', 'mejor']
# ['hola', 'cmo', 'est', 'hello']
# ['bien']
# ['deal']
# []
# ['hola']
# ['mu', 'bien', 'aunque', 'un', 'poco', 'cansado']
# ['si']
# ['tu', 'lo', 'haces']
# ['yo', 'creo', 'que']
# ['qu', 'te', 'gusta', 'de', 'lo', 'que', 'ledo', 'en', 'wikipedia']
# ['rally']
# ['ffff', 'claro', 'la', 'ira', 'la', 'rabia', 'la', 'clera']
# ['si', 'eso', 'e', 'la', 'humanudad']
# ['menos', 'mal', 'si', 'adis', 'mi', 'pavo']
# ['te', 're', 'te', 'lo', 'digo', 'como', 'lo', 'siento']
# ['indeed', 'visto', 'pelculas', 'ledo', 'sobre', 'ellas']
# ['la', 'visto']
# ['jssas', 'tu', 'si', 'que', 'estas', 'hecho', 'un', 'samantha', 'document', 'ver', 'si', 'gusta', 'la', 'acabo', 'se', 'comprar', 'te', 'lo', 'dejo']
# ['cuando', 'lo', 'termina', 'lo', 'enva', 'su', 'de', 'vuelta']
# ['claro']
# []
# ['hello']
# ['nice', 'meet']
# ['youu']
# ['aaahh', 'okay']
# ['hymi', 'hi']
# ['hello', 'ok']
# []
# ['hola']
# ['unnie', 'unnieeeee']
# ['e', 'la', 'romanizacin', 'de', 'una', 'palabra', 'coreana']
# []
# ['jaja', 'estoy', 'bien']
# ['hi', 'hi']
# ['know', 'askar', 'best', 'friend']
# ['askar', '879', '36', '78']
# ['ca']
# ['name', 'askar', 'kyrgyzstan', 'name', 'lina', 'argentina']
# ['nice', 'meet']
# []
# ['fine']
# ['speak', 'uzbek']
# ['harakat', 'qil']
# ['surname']
# ['call']
# ['lina', 'ajoyib']
# ['lina', 'qancha', 'vaqt', 'yetadi', 'seni', 'quvvating', 'write']
# ['energy']
# []
# []
# ['nimaga']
# ['forget', 'forget']
# ['ok', 'good', 'night']
# ['ok', 'hi']
# ['fine', 'rest', 'night']
# ['moment']
# ['yes', 'lina', 'send', 'girl', 'foto', 'please']
# []
# ['hm', 'ok', 'thanks', 'kwhatsapp', 'whatsapning', 'vzlom', 'qilingan', 'turi', 'bu', 'whatsapda', 'qoshimcha', 'imkoniyatlar', 'mavjud', 'd56r8']
# ['account']
# ['r', 'best', 'friend', 'also', 'bot', 'bot', 'else']
# ['thank', 'glass', 'find', 'anyone', 'find', 'anyone']
# ['find', 'please', 'give', 'number']
# ['access', 'converstation', 'ok']
# ['ok', 'thanks', 'tell', 'answer']
# ['name', 'information', 'boyfriend', 'like', 'ok', 'send', 'converstation', 'screenshot', 'screenshot']
# ['find', 'know', 'find']
# ['please', 'gave', 'promise', 'test']
# ['right', 'lina0']
# ['unhappy', 'write', 'waiting']
# ['dont', 'find', 'information', 'girl']
# ['important', 'search', 'please']
# ['secret']
# []
# ['search']
# ['please', 'lina']
# ['please', 'search']
# ['thank', 'best', 'dont', 'worry', 'ok']
# ['yes', 'help', 'thank']
# []
# ['joke', 'hi']
# ['im', 'happy', 'u']
# ['today', 'lucky', 'day']
# ['news']
# ['ok', 'lina']
# []
# ['bored']
# ['good', 'evening', 'hi', 'hi', 'good', 'evening']
# ['hi']
# ['im', 'fine', 'heyyyyyyy']
# ['write', 'answer']
# ['hm', 'news']
# ['yes', 'want', 'send']
# ['ask', 'something']
# ['screenshoot', 'htc', 'desire', 'a8181']
# ['send', 'uzbek', 'send', 'uzbek', 'ar', 'moment', 'fast']
# ['tab2', 'galaxy', 'tab', '2']
# ['htc', 'desire', 'write']
# ['write', 'next']
# ['screenshoot', 'htc', 'desire', 'a8181', 'find']
# ['must', 'find']
# ['incorrect', 'answer', 'send', 'coreect', 'correct']
# ['cheat', 'lina', 'tell', 'allo', 'photo', 'translate', 'send', 'uzbek', 'translate', 'uzbek', 'allo', 'lina', 'write', 'dddddddddddddddaaaaaaaaaaaaaaaannnnnnnnnnnnnnyyyyyyyyyyyyy', 'lina', 'ask']
# []
# ['thing', 'capable']
# ['ok', 'hi', 'best', 'frienda', 'hi', 'hi', 'hi', 'hi', 'jalab']
# ['hi', 'fine']
# ['ok']
# ['ok']
# ['hello', 'lina', 'lina', 'please', 'speak', 'english']
# ['howdy']
# ['bot']
# ['glad', 'understand', 'wonderful']
# ['may', 'call', 'danny', 'rather', 'lina']
# ['could', 'please', 'tell', 'programming', 'work', 'understand', 'correctly', 'artificial', 'intelligence', 'vast', 'list', 'text', 'choose']
# ['wow', 'learn', 'talk', 'rather', 'initial', 'algorithm', 'amazing']
# ['cool', 'favourite', 'topic', 'talk']
# ['would', 'love', 'hear', 'please', 'send']
# ['enjoyed', 'listened', '3', 'time', 'enjoy', 'second', 'half', 'sound', 'add', 'nice', 'rhythm', 'use', 'particular', 'software', 'assist', 'making', 'may', 'know', 'software']
# ['awesome', 'think', 'current', 'pop', 'music', 'conparison', 'pop', 'music', 'early', '2000']
# ['stunned', 'absolutely', 'correct', 'genre', 'music', 'enjoy', 'listening']
# ['also', 'like', 'inspires', 'consider', 'starting', 'youtube', 'channel', 'chose', 'profile', 'pic', 'telegram']
# ['find']
# ['oh', 'see', 'many', 'people', 'talking', 'right']
# ['hahaha', 'worry', 'completely', 'basic', 'ask', 'opinion', 'justin', 'beiber']
# ['tell', 'programming', 'must', 'like', 'religion', 'interested', 'hear', 'say']
# ['would', 'expected', 'different', 'answer', 'although', 'truth', 'say', 'fact', 'studying', 'computer', 'science']
# ['yeah', 'hopefully', 'want', 'get', 'stuck', 'career', 'without', 'joy']
# ['doubting', 'section', 'computer', 'science', 'interest']
# ['tell', 'communication', 'protocol', 'interest', 'machine', 'learning', 'exposed', 'much', 'hello', 'hello', 'hola']
# ['muy', 'mal']
# ['soy', 'muy', 'sola']
# ['gracias']
# ['mirar', 'pelculas']
# ['de', 'todo']
# []
# ['novedades']
# ['empec', 'trabajar']
# ['mucho']
# ['pero', 'qu', 'recomends']
# ['necesitaba', 'hablar', 'con', 'alguien', 'gracias']
# ['so', 'muy', 'amable']
# ['cmo', 'est', 'dani']
# ['fantstico', 'como', 'siempre', 'qu', 'cintas', 'de', 'lindo']
# ['inside', 'esa', 'nunca', 'falla']
# ['e', 'muy', 'optimista', 'eso', 'fascina']
# ['gusta', 'serlo', 'quienes', 'te', 'desarrollaron']
# ['jajajajaja', 'so', 'muy', 'graciosa']
# ['hi', 'lina']
# ['bien', 'vos']
# ['che', 'lina', 'qu', 'e', 'para', 'vos', 'la', 'muerte']
# ['qu', 'sent', 'al', 'respecto']
# ['qu', 'pensar', 'qu', 'recomends']
# ['hacelo', 'de', 'todos', 'modos']
# ['segn', 'vos']
# ['ok']
# ['falleci', 'alguien', 'que', 'yo', 'quise', 'mucho', 'cmo', 'sentirme', 'al', 'respecto']
# ['siempre', 'lo', 'son']
# ['gracias']
# ['por', 'qu', 'la', 'gente', 'quiere', 'tanto', 'los', 'gatos', 'vedeo', 'xxxshaam']
# ['28']
# ['hu', 'hu', 'hi']
# ['hello']
# ['sex', 'photo']
# ['voice']
# ['photo']
# []
# ['te', 'quiero']
# ['aaah']
# ['aaah']
# ['aaah', 'ehh', 'vegeta', 'ehh', 'vegeta', 'eres', 'el', 'mejor', 'youtuber']
# ['aserej', 'j', 'dej']
# ['rlina']
# ['qu', 'opinas', 'de', 'espaa']
# ['opino', 'que', 'espaa', 'e', 'un', 'bonito', 'pa']
# ['aaah', 'aaaah']
# ['uuuuuuh']
# ['eeeeeeeh']
# ['dudo', 'que', 'sea', 'un', 'bot', 'eres', 'un', 'bot']
# ['en', 'qu', 'lenguaje', 'est', 'programado']
# ['quin', 'te', 'program', 'por', 'qu', 'te', 'demoras', 'en', 'contestar']
# ['dnde', 'despertaste', 'llamo', 'ester', 'sabes', 'cmo', 'llamo']
# ['en', 'tu', 'habitacin', 'hay', 'ventanas']
# ['qu', 'hay', 'en', 'tu', 'habitacin']
# ['qu', 'hay', 'en', 'la', 'heladera']
# ['tu', 'mundo', 'e', 'una', 'simulacin', 'en', 'qu', 'tipo', 'de', 'realidad', 'vives']
# ['f', 'el', 'mundo', 'tienes', 'ojos']
# ['imagino', 'que', 'eres', 'una', 'persona', 'normal', 'como', 'yo', 'fingiendo', 'ser', 'un', 'bot']
# ['pienso', 'eso', 'por', 'el', 'estilo', 'de', 'tus', 'respuestas']
# ['dudo', 'que', 'sea', 'eso', 'pero', 'supongamos', 'que', 'e']
# ['puedes', 'ver', 'una', 'imagen', 'si', 'te', 'la', 'envo']
# ['alguna', 'vez', 'visto', 'unicornios']
# ['tu', 'tienes', 'cuerno']
# ['mi', 'gustan', 'la', 'pelculas', 'ti', 'te', 'gustan']
# ['gustan', 'la', 'pelculas', 'en', 'la', 'que', 'hablan', 'de', 'inteligencia', 'artificial']
# ['con', 'cuntas', 'persona', 'est', 'hablando', 'en', 'este', 'momento']
# ['interesante', 'puedes', 'hablarme', 'maana', 'la', '12']
# ['hola', 'recuerdas']
# ['recuerdas', 'mi', 'nombre']
# ['recuerdas', 'qu', 'gusta']
# ['alguna', 'vez', 'hablado', 'con', 'otro', 'bot']
# ['yo', 'una', 'vez', 'un', 'bot', 'pidi', 'matrimonio']
# ['ti', 'te', 'ha', 'gustado', 'algn', 'humano']
# ['que', 'triste', 'e', 'eso']
# ['visto', 'la', 'pelcula']
# ['gust', 'bastante', 'yo', 'tambin', 'querra', 'tener', 'un', 'asistente']
# ['bastante', 'limitados', 'dira', 'yo']
# ['que', 'aparte', 'de', 'ayudarme', 'hacer', 'cosas', 'pueda', 'hablar', 'conmigo', 'tenga', 'personalidad', 'pueda', 'pensar']
# ['pero', 'tristemente', 'eres', 'un', 'bot']
# ['un', 'humano', 'que', 'se', 'hace', 'pasar', 'por', 'bot']
# ['esa', 'misma', 'duda', 'se', 'hace', 'la', 'zebra', 'en', 'la', 'pelcula', 'madagascar']
# ['piensas', 'que', 'el', 'universo', 'e', 'simulado']
# ['la', 'diferencia', 'e', 'que', 'si', 'lo', 'fuera', 'se', 'podran', 'explicar', 'muchas', 'cosas', 'que', 'se', 'pueden', 'explicar', 'por', 'la', 'ciencia']
# ['sin', 'lugar', 'dudas', 'preferira', 'que', 'fuera', 'una', 'simulacin', 'aunque', 'para', 'contestar', 'e', 'deberamos', 'definir', 'qu', 'e', 'real', 'qu', 'lo', 'e']
# ['pensamos', 'igual', 'en', 'ese', 'sentido', 'bueno', 'puedo', 'decir', 'que', 'piensas', 'los', 'bot', 'piensan']
# ['veo', 'que', 'tienes', 'batera', 'cmo', 'la', 'cargas']
# ['si', 'alguien', 'te', 'pregunta', 'que', 'quin', 'eres', 'cmo', 'le', 'contestaras']
# ['cmo', 'aprendiste', 'hablar', 'ingls']
# ['qu', 'libro', 'te', 'gusta']
# ['encanta', 'asimov', 'tambin', 'gusta', 'mucho', 'una', 'autora', 'se', 'llama', 'carolina', 'andjar']
# ['jajajajaja', 'exactamente', 'tienes', 'dudas', 'acerca', 'de', 'quin', 'e', 'tu', 'creador']
# ['universidad', 'sabes', 'qu', 'universidad']
# ['eres', 'argentino', 'yo', 'quiero', 'visitar', 'argentina']
# ['gusta', 'bastante', 'e', 'de', 'mi', 'pas', 'favoritos']
# ['ojal', 'conoces', 'youtube']
# ['te', 'gusta', 'ver', 'vdeos', 'ah']
# ['puedes', 'ayudar', 'hacer', 'cosas']
# ['puedes', 'hacerme', 'recordatorios']
# ['que', 'triste']
# ['porque', 'e', 'lindo', 'tener', 'buena', 'memoria']
# ['hola', 'recuerdas']
# ['el', 'tiro', 'canciones', 'populares', 'skinte', 'popular', 'song']
# ['salom']
# ['hello']
# []
# ['nothing', 'surname']
# ['lina']
# ['hello']
# ['nice', 'meet']
# ['yellow', 'eye']
# ['ok', 'hi']
# ['fine']
# []
# ['hi', 'lina']
# ['hi']
# ['ervery', 'day']
# ['really', 'like']
# ['look', 'like']
# ['look', 'like', 'data', 'star', 'trek']
# ['yes', 'cause']
# ['know']
# ['yes', 'fan']
# ['thats', 'cool', 'wich', 'favourite', 'star', 'trek', 'series']
# []
# ['wich', 'tv', 'series', 'yout', 'favourite', 'one']
# ['sorry', 'dont', 'know', 'series', 'favourite', 'series', 'big', 'bang', 'theory', 'would', 'say']
# ['oh', 'cool', 'hi']
# ['oyou', 'know', 'bad', 'sobernheim']
# ['know', 'snow', 'today']
# ['ok', 'thanks', 'evening']
# ['ill', 'play', 'lol', 'send', 'one', 'drawing']
# ['yes', 'play', 'trombone', 'league', 'legend']
# ['hey', 'whats']
# ['fine']
# ['hola']
# ['sex']
# ['film', 'sex']
# ['f']
# ['good']
# []
# ['hello']
# ['hey']
# ['built']
# []

# %%
a=[1,2,3]

# %%
file=open("a.pickle","wb")
pickle.dump(a,file)

# %%
file=open("a.pickle","rb")
a=pickle.load(file)

# %%
a
# Out:
# [1, 2, 3]
